# %%
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
import skimage
from sklearn.cluster import KMeans
from skimage import io
from skimage import color
from skimage import data
import cv2
import os, glob
import tools

# %%
image_paths = os.listdir("Data")

# %%
# Select the desired image
index = 0

image = skimage.io.imread("Data/" + image_paths[index])

# %%
#Select the number of clusters
clusters = 7 

width = 700
height = 200

# %%
#Select the colors to be displayed
selection = [0,1,2,3,4,5,6]

# %%
plt.imshow(image, aspect = 'auto')

# %% [markdown]
# #### RGB

# %%
colors, labels = tools.colorAnalyzerRGB(clusters, image)
plt.imshow(tools.recolor(image, selection, colors, labels))
tools.histogram(colors, labels, width, height)

# %% [markdown]
# #### LAB

# %%
colors, labels = tools.colorAnalyzerLAB(clusters, image)
plt.imshow(tools.recolor(image, selection, colors, labels))
tools.histogram(colors, labels, width, height)

# %% [markdown]
# #### HSV

# %%
colors, labels = tools.colorAnalyzerHSV(clusters, image)
plt.imshow(tools.recolor(image, selection, colors, labels))
tools.histogram(colors, labels, width, height)

# %% [markdown]
# #### XYZ

# %%
colors, labels = tools.colorAnalyzerXYZ(clusters, image)
plt.imshow(tools.recolor(image, selection, colors, labels))
tools.histogram(colors, labels, width, height)

# %% [markdown]
# #### CIERGB

# %%
colors, labels = tools.colorAnalyzerRGBCIE(clusters, image)
plt.imshow(tools.recolor(image, selection, colors, labels))
tools.histogram(colors, labels, width, height)
