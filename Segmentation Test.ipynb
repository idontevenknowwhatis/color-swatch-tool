# %%
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
import skimage
from sklearn.cluster import KMeans
from skimage import io
from skimage import color
from skimage import data
from skimage.segmentation import felzenszwalb, quickshift, slic
import cv2
import os, glob
import tools
from tools import posterizationSLIC, posterizationFelzen, posterizationQuickshift, posterizationChan
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.

# %%
image_paths = os.listdir("Data")
index = 1
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 10, 5, 10000, 3, (15,15) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationChan(image, 2, 1.0, 1.0, [5,5])
skimage.io.imsave(str(index) + "Chan.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # Image 2

# %%
image_paths = os.listdir("Data")
index = 2
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 5, 5, 10000, 3, (5,5) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# recolored = posterizationChan(image, 1, 1.0, 1.0, [5,5])
# skimage.io.imsave(str(index) + "Chan.jpg", recolored)
# plt.imshow(recolored)

# %% [markdown]
# # Image 3

# %%
image_paths = os.listdir("Data")
index = 3
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 10, 5, 10000, 3, (15,15) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationChan(image, 2, 1.0, 1.0, [5,5])
skimage.io.imsave(str(index) + "Chan.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # Image 5

# %%
image_paths = os.listdir("Data")
index = 5
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 10, 5, 10000, 3, (15,15) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationChan(image, 2, 1.0, 1.0, [5,5])
skimage.io.imsave(str(index) + "Chan.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # Image 6

# %%
image_paths = os.listdir("Data")
index = 6
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 10, 5, 10000, 3, (15,15) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)

# %%
recolored = posterizationChan(image, 2, 1.0, 1.0, [5,5])
skimage.io.imsave(str(index) + "Chan.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # Image 7

# %%
image_paths = os.listdir("Data")
index = 7
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 10, 5, 10000, 3, (15,15) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationChan(image, 2, 1.0, 1.0, [5,5])
skimage.io.imsave(str(index) + "Chan.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # Image 8

# %%
image_paths = os.listdir("Data")
index = 8
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 10, 5, 10000, 3, (15,15) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationChan(image, 2, 1.0, 1.0, [5,5])
skimage.io.imsave(str(index) + "Chan.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # Image 9

# %%
image_paths = os.listdir("Data")
index = 9
# image = skimage.io.imread("Data/" + image_paths[index])
image = skimage.io.imread("Data/" + str(index) + ".jpg")

# %%
plt.imshow(image)
recolored = posterizationSLIC(image, 150, 5, 5,  2, (5,5) )
skimage.io.imsave(str(index) + "SLIC.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationFelzen(image, 10, 5, 10000, 3, (15,15) )
skimage.io.imsave(str(index) + "Felzen.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
recolored = posterizationChan(image, 2, 1.0, 1.0, [5,5])
skimage.io.imsave(str(index) + "Chan.jpg", recolored)
plt.imshow(recolored)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
